# %% [markdown]
# The code here is the current best.  Development is not to be done here, but tests may be run.

# %%
def AttemptProof(modulus, residue):
    def multiplyBy2(modulus,residue,proof):
        proof.append(2)
        modulus = 2*modulus
        residue = 2*residue
        return modulus, residue, proof
    def divideBy3(modulus,residue,proof):
        proof.append(3)
        modulus = modulus // 3
        residue = (residue - 1) // 3
        return modulus, residue, proof
    def count3s(modulus):
        i = 0
        while ((modulus % 3) == 0) and (modulus > 0):
            i = i + 1
            modulus = modulus // 3
        return i
    m = modulus
    r = residue
    proof = ['U', m, r, [], 0]
    count = count3s(m)
    if ((r % 3) == 2) and ((m % 3) == 0):
        proof = ['3-2', m, r, [], 0]
    elif ((r % 8) == 5) and ((m % 8) == 0):
        proof = ['8-5', m, r, [], 0]
    elif ((r % 16) == 3) and ((m % 16) == 0):
        proof = ['16-3', m, r, [], 0]
    elif ((r % 64) == 25) and ((m % 64) == 0):
        proof = ['64-25', m, r, [], 0]
    elif ((r % 512) == 33) and ((m % 512) == 0):
        proof = ['512-33', m, r, [], 0]
    elif ((r % 1024) == 363) and ((m % 1024) == 0):
        proof = ['1024-363', m, r, [], 0]
    elif ((r % 2) == 0) and ((m % 2) == 0):
        proof = ['E', m, r, [], 0]
    else:
        i = 0
        proved = False
        while (i < count) and (proved == False):
            mod3 = (r % 3)
            if mod3 == 1:
                m,r,proof[3] = multiplyBy2(m,r,proof[3])
                m,r,proof[3] = multiplyBy2(m,r,proof[3])
                m,r,proof[3] = divideBy3(m,r,proof[3])
            elif mod3 == 2:
                m,r,proof[3] = multiplyBy2(m,r,proof[3])
                m,r,proof[3] = divideBy3(m,r,proof[3])
            else:
                m,r,proof[3] = multiplyBy2(m,r,proof[3])
                m,r,proof[3] = multiplyBy2(m,r,proof[3])
                m,r,proof[3] = multiplyBy2(m,r,proof[3])
                m,r,proof[3] = multiplyBy2(m,r,proof[3])
                m,r,proof[3] = divideBy3(m,r,proof[3])
            if (m < modulus) or ((m == modulus) and (r < residue)):
                proved = True
            i = i + 1
        proof[4] = i
        if proved == True:
            proof[0] = 'I'
    return proof

# %%
from datetime import datetime  
def SLengthRecords(end, 
                    start=106241, 
                    ladderinteger=[106239, 77031, 52527, 35655, 35497, 26623, 23529, 
                                   17673, 13255, 10971, 6171, 3711, 2919, 2463, 2323, 871, 
                                   703, 667, 313, 235, 171, 129, 97, 73, 55, 25, 9, 7, 3, 1], 
                    recordinteger=[1, 3, 7, 9, 25, 27, 73, 97, 129, 171, 231, 313, 327, 703, 871, 
                                   1161, 2463, 2919, 3711, 6171, 10971, 13255, 17647, 23529, 
                                   26623, 34239, 35655, 52527, 77031, 106239], 
                    recordodds=[0, 2, 5, 6, 7, 41, 42, 43, 44, 45, 46, 47, 52, 62, 65, 66, 76, 
                                79, 87, 96, 98, 101, 102, 103, 113, 114, 119, 125, 129, 130],                    
                    printlines = False):
                     
    starttime = datetime.now().timestamp()
    lasttime = starttime
    ladderlength = len(ladderinteger) - 1
    ladderodds = [recordodds[-i] for i in range(1,len(recordodds)+1)]
    currentrecordodds = ladderodds[0]
    
    # generated by laddergenerator
    i1 = ladderinteger[1]
    i2 = ladderinteger[2]
    i3 = ladderinteger[3]
    i4 = ladderinteger[4]
    i5 = ladderinteger[5]
    i6 = ladderinteger[6]
    i7 = ladderinteger[7]
    i8 = ladderinteger[8]
    i9 = ladderinteger[9]
    i10 = ladderinteger[10]
       # if i == special: print("{} made it past APRIORI, n = {}, odds = {}".format(special,n,odds))
    
        while n != 1:  
            
            # generated by equivalencegenerator
            res = (n % 256)
            if res < 128:
                if res < 64:
                    if res < 32:
                        if res < 16:
                            if res < 8:
                                if res < 4:
                                    if res == 1: n = (81*n + 175) // 256; odds = odds + 3
                                    else: n = (81*n + 269) // 256; odds = odds + 3
                                else:
                                    if res == 5: n = (27*n + 121) // 256; odds = odds + 2
                                    else: n = (243*n + 347) // 256; odds = odds + 4
                            else:
                                if res < 12:
                                    if res == 9: n = (243*n + 373) // 256; odds = odds + 4
                                    else: n = (81*n + 133) // 256; odds = odds + 3
                                else:
                                    if res == 13: n = (27*n + 161) // 256; odds = odds + 2
                                    else: n = (81*n + 65) // 256; odds = odds + 3
                        else:
                            if res < 24:
                                if res < 20:
                                    if res == 17: n = (27*n + 53) // 256; odds = odds + 2
                                    else: n = (243*n + 503) // 256; odds = odds + 4
                                else:
                                    if res == 21: n = (9*n + 67) // 256; odds = odds + 1
                                    else: n = (81*n + 185) // 256; odds = odds + 3
                            else:
                                if res < 28:
                                    if res == 25: n = (243*n + 581) // 256; odds = odds + 4
                                    else: n = (2187*n + 2903) // 256; odds = odds + 6
                                else:
                                    if res == 29: n = (81*n + 211) // 256; odds = odds + 3
                                    else: n = (729*n + 697) // 256; odds = odds + 5
                    else:
                        if res < 48:
                            if res < 40:
                                if res < 36:
                                    if res == 33: n = (81*n + 143) // 256; odds = odds + 3
                                    else: n = (27*n + 79) // 256; odds = odds + 2
                                else:
                                    if res == 37: n = (81*n + 331) // 256; odds = odds + 3
                                    else: n = (243*n + 251) // 256; odds = odds + 4
                            else:
                                if res < 44:
                                    if res == 41: n = (729*n + 1087) // 256; odds = odds + 5
                                    else: n = (81*n + 101) // 256; odds = odds + 3
                                else:
                                    if res == 45: n = (27*n + 65) // 256; odds = odds + 2
                                    else: n = (729*n + 809) // 256; odds = odds + 5
                        else:
                            if res < 56:
                                if res < 52:
                                    if res == 49: n = (81*n + 383) // 256; odds = odds + 3
                                    else: n = (81*n + 221) // 256; odds = odds + 3
                                else:
                                    if res == 53: n = (9*n + 35) // 256; odds = odds + 1
                                    else: n = (729*n + 1121) // 256; odds = odds + 5
                            else:
                                if res < 60:
                                    if res == 57: n = (243*n + 485) // 256; odds = odds + 4
                                    else: n = (81*n + 85) // 256; odds = odds + 3
                                else:
                                    if res == 61: n = (81*n + 179) // 256; odds = odds + 3
                                    else: n = (729*n + 665) // 256; odds = odds + 5
                else:
                    if res < 96:
                        if res < 80:
                            if res < 72:
                                if res < 68:
                                    if res == 65: n = (27*n + 37) // 256; odds = odds + 2
                                    else: n = (81*n + 205) // 256; odds = odds + 3
                                else:
                                    if res == 69: n = (27*n + 185) // 256; odds = odds + 2
                                    else: n = (729*n + 977) // 256; odds = odds + 5
                            else:
                                if res < 76:
                                    if res == 73: n = (243*n + 437) // 256; odds = odds + 4
                                    else: n = (27*n + 23) // 256; odds = odds + 2
                                else:
                                    if res == 77: n = (81*n + 419) // 256; odds = odds + 3
                                    else: n = (243*n + 259) // 256; odds = odds + 4
                        else:
                            if res < 88:
                                if res < 84:
                                    if res == 81: n = (243*n + 797) // 256; odds = odds + 4
                                    else: n = (729*n + 1445) // 256; odds = odds + 5
                                else:
                                    if res == 85: n = (3*n + 1) // 256
                                    else: n = (81*n + 121) // 256; odds = odds + 3
                            else:
                                if res < 92:
                                    if res == 89: n = (81*n + 215) // 256; odds = odds + 3
                                    else: n = (729*n + 989) // 256; odds = odds + 5
                                else:
                                    if res == 93: n = (27*n + 49) // 256; odds = odds + 2
                                    else: n = (243*n + 211) // 256; odds = odds + 4
                    else:
                        if res < 112:
                            if res < 104:
                                if res < 100:
                                    if res == 97: n = (243*n + 493) // 256; odds = odds + 4
                                    else: n = (27*n + 143) // 256; odds = odds + 2
                                else:
                                    if res == 101: n = (27*n + 89) // 256; odds = odds + 2
                                    else: n = (2187*n + 2579) // 256; odds = odds + 6
                            else:
                                if res < 108:
                                    if res == 105: n = (243*n + 341) // 256; odds = odds + 4
                                    else: n = (243*n + 367) // 256; odds = odds + 4
                                else:
                                    if res == 109: n = (243*n + 905) // 256; odds = odds + 4
                                    else: n = (729*n + 745) // 256; odds = odds + 5
                        else:
                            if res < 120:
                                if res < 116:
                                    if res == 113: n = (9*n + 7) // 256; odds = odds + 1
                                    else: n = (81*n + 157) // 256; odds = odds + 3
                                else:
                                    if res == 117: n = (27*n + 169) // 256; odds = odds + 2
                                    else: n = (81*n + 89) // 256; odds = odds + 3
                            else:
                                if res < 124:
                                    if res == 121: n = (729*n + 1391) // 256; odds = odds + 5
                                    else: n = (243*n + 319) // 256; odds = odds + 4
                                else:
                                    if res == 125: n = (243*n + 601) // 256; odds = odds + 4
                                    else: n = (2187*n + 2059) // 256; odds = odds + 6
            else:
                if res < 192:
                    if res < 160:
                        if res < 144:
                            if res < 136:
                                if res < 132:
                                    if res == 129: n = (243*n + 653) // 256; odds = odds + 4
                                    else: n = (27*n + 47) // 256; odds = odds + 2
                                else:
                                    if res == 133: n = (81*n + 491) // 256; odds = odds + 3
                                    else: n = (81*n + 73) // 256; odds = odds + 3
                            else:
                                if res < 140:
                                    if res == 137: n = (729*n + 1247) // 256; odds = odds + 5
                                    else: n = (243*n + 527) // 256; odds = odds + 4
                                else:
                                    if res == 141: n = (9*n + 11) // 256; odds = odds + 1
                                    else: n = (243*n + 323) // 256; odds = odds + 4
                        else:
                            if res < 152:
                                if res < 148:
                                    if res == 145: n = (81*n + 287) // 256; odds = odds + 3
                                    else: n = (81*n + 125) // 256; odds = odds + 3
                                else:
                                    if res == 149: n = (27*n + 329) // 256; odds = odds + 2
                                    else: n = (27*n + 19) // 256; odds = odds + 2
                            else:
                                if res < 156:
                                    if res == 153: n = (81*n + 151) // 256; odds = odds + 3
                                    else: n = (729*n + 925) // 256; odds = odds + 5
                                else:
                                    if res == 157: n = (243*n + 761) // 256; odds = odds + 4
                                    else: n = (2187*n + 2219) // 256; odds = odds + 6
                    else:
                        if res < 176:
                            if res < 168:
                                if res < 164:
                                    if res == 161: n = (243*n + 557) // 256; odds = odds + 4
                                    else: n = (81*n + 365) // 256; odds = odds + 3
                                else:
                                    if res == 165: n = (243*n + 1121) // 256; odds = odds + 4
                                    else: n = (729*n + 881) // 256; odds = odds + 5
                            else:
                                if res < 172:
                                    if res == 169: n = (2187*n + 3389) // 256; odds = odds + 6
                                    else: n = (243*n + 431) // 256; odds = odds + 4
                                else:
                                    if res == 173: n = (81*n + 323) // 256; odds = odds + 3
                                    else: n = (243*n + 227) // 256; odds = odds + 4
                        else:
                            if res < 184:
                                if res < 180:
                                    if res == 177: n = (27*n + 85) // 256; odds = odds + 2
                                    else: n = (27*n + 31) // 256; odds = odds + 2
                                else:
                                    if res == 181: n = (27*n + 233) // 256; odds = odds + 2
                                    else: n = (243*n + 331) // 256; odds = odds + 4
                            else:
                                if res < 188:
                                    if res == 185: n = (81*n + 119) // 256; odds = odds + 3
                                    else: n = (243*n + 383) // 256; odds = odds + 4
                                else:
                                    if res == 189: n = (243*n + 665) // 256; odds = odds + 4
                                    else: n = (2187*n + 2123) // 256; odds = odds + 6
                else:
                    if res < 224:
                        if res < 208:
                            if res < 200:
                                if res < 196:
                                    if res == 193: n = (81*n + 239) // 256; odds = odds + 3
                                    else: n = (243*n + 743) // 256; odds = odds + 4
                                else:
                                    if res == 197: n = (9*n + 19) // 256; odds = odds + 1
                                    else: n = (243*n + 283) // 256; odds = odds + 4
                            else:
                                if res < 204:
                                    if res == 201: n = (81*n + 103) // 256; odds = odds + 3
                                    else: n = (81*n + 197) // 256; odds = odds + 3
                                else:
                                    if res == 205: n = (27*n + 97) // 256; odds = odds + 2
                                    else: n = (729*n + 905) // 256; odds = odds + 5
                        else:
                            if res < 216:
                                if res < 212:
                                    if res == 209: n = (81*n + 223) // 256; odds = odds + 3
                                    else: n = (243*n + 439) // 256; odds = odds + 4
                                else:
                                    if res == 213: n = (9*n + 131) // 256; odds = odds + 1
                                    else: n = (243*n + 491) // 256; odds = odds + 4
                            else:
                                if res < 220:
                                    if res == 217: n = (27*n + 29) // 256; odds = odds + 2
                                    else: n = (243*n + 287) // 256; odds = odds + 4
                                else:
                                    if res == 221: n = (81*n + 275) // 256; odds = odds + 3
                                    else: n = (729*n + 761) // 256; odds = odds + 5
                    else:
                        if res < 240:
                            if res < 232:
                                if res < 228:
                                    if res == 225: n = (729*n + 1607) // 256; odds = odds + 5
                                    else: n = (9*n + 5) // 256; odds = odds + 1
                                else:
                                    if res == 229: n = (81*n + 395) // 256; odds = odds + 3
                                    else: n = (729*n + 817) // 256; odds = odds + 5
                            else:
                                if res < 236:
                                    if res == 233: n = (729*n + 1151) // 256; odds = odds + 5
                                    else: n = (729*n + 1229) // 256; odds = odds + 5
                                else:
                                    if res == 237: n = (81*n + 259) // 256; odds = odds + 3
                                    else: n = (2187*n + 2363) // 256; odds = odds + 6
                        else:
                            if res < 248:
                                if res < 244:
                                    if res == 241: n = (27*n + 149) // 256; odds = odds + 2
                                    else: n = (243*n + 599) // 256; odds = odds + 4
                                else:
                                    if res == 245: n = (81*n + 635) // 256; odds = odds + 3
                                    else: n = (243*n + 395) // 256; odds = odds + 4
                            else:
                                if res < 252:
                                    if res == 249: n = (243*n + 421) // 256; odds = odds + 4
                                    else: n = (729*n + 1085) // 256; odds = odds + 5
                                else:
                                    if res == 253: n = (729*n + 1931) // 256; odds = odds + 5
                                    else: n = (6561*n + 6305) // 256; odds = odds + 7
                                        
            #if i == special: print("{} made it past LOOP, n = {}, mod128 = {}, odds = {}".format(special,n,n%128,odds))
                
            if n != 1:
                while not (n & 1):
                    if ((n % 4) == 0):
                        if ((n % 8) == 0):
                            if ((n % 16) == 0):
                                if ((n % 32) == 0):
                                    if ((n % 64) == 0):
                                        if ((n % 128) == 0):
                                            if ((n % 256) == 0):
                                                if ((n % 512) == 0):
                                                    n = n // 512
                                                else: n = n // 256
                                            else: n = n // 128
                                        else: n = n // 64
                                    else: n = n // 32
                                else: n = n // 16
                            else: n = n // 8
                        else: n = n // 4                                
                    else: n = n // 2
                odds = odds + 1
            
            #if i == special: print("{} made it past DIV BY 2, n = {}, odds = {}".format(special,n,odds))
                
            if n < smalloddssize:               
                if n < 4000:
                    if n < 2000:
                        if n < 1000: odds = odds + smallodds1[n]
                        else: odds = odds + smallodds2[n]
                    else:
                        if n < 3000: odds = odds + smallodds3[n]
                        else: odds = odds + smallodds4[n]
                else:
                    if n < 6000:
                        if n < 5000: odds = odds + smallodds5[n]
                        else: odds = odds + smallodds6[n]
                    else:
                        if n < 7000: odds = odds + smallodds7[n]
                        else: odds = odds + smallodds8[n]
                n = 1
                #break
            else:
                newodds = currentrecordodds - odds
                
                # generated by laddergenerator
                if n <= i1:
                    if o1 <= newodds: n = 1
                    elif n <= i2:
                        if o2 <= newodds: n = 1
                        elif n <= i3:
                            if o3 <= newodds: n = 1
                            elif n <= i4:
                                if o4 <= newodds: n = 1
                                elif n <= i5:
                                    if o5 <= newodds: n = 1
                                    elif n <= i6:
                                        if o6 <= newodds: n = 1
                                        elif n <= i7:
                                            if o7 <= newodds: n = 1
                                            elif n <= i8:
                                                if o8 <= newodds: n = 1
                                                elif n <= i9:
                                                    if o9 <= newodds: n = 1
                                                    elif n <= i10:
                                                        if o10 <= newodds: n = 1
                                                        elif n <= i11:
                                                            if o11 <= newodds: n = 1
                                                            elif n <= i12:
                                                                if o12 <= newodds: n = 1
                                                                elif n <= i13:
                                                                    if o13 <= newodds: n = 1
                                                                    elif n <= i14:
                                                                        if o14 <= newodds: n = 1
                                                                        elif n <= i15:
                                                                            if o15 <= newodds: n = 1
                                                                            else:
                                                                                j = 16

                                                                                while (j < ladderlength) and (n <= ladderinteger[j]):        
                                                                                    if ladderodds[j] <= newodds:
                                                                                        n = 1
                                                                                        break
                                                                                    j = j + 1

        #if i == special: print("{} made it past LADDER, n = {}, odds = {}, recordodds = {}, currentladder = {}".
        #                       format(special,n,odds,currentrecordodds,ladderinteger[0]))
            
        # update ladder if a full count meets previous record
        if currentrecordodds == odds:
            ladderinteger[0] = i 
            
           # if i == special: print("{} UPDATE LADDER, n = {}, odds = {}, recordodds = {}, currentladder = {}".
                 #                  format(special,n,odds,currentrecordodds,ladderinteger[0]))
                
        # log a new record reseting variables
        elif currentrecordodds < odds:
           # if printlines:
           #     print("{} {} {}".format(i,odds,datetime.now().timestamp()-lasttime))
           #     lasttime = datetime.now().timestamp()
            recordinteger.append(i)
            recordodds.append(odds)
            currentrecordodds = odds
            ladderinteger.insert(0,i)
            ladderodds.insert(0,odds)
            ladderlength = ladderlength + 1
            
            # generated by laddergenerator
            i1 = ladderinteger[1]
            i2 = ladderinteger[2]
            i3 = ladderinteger[3]
            i4 = ladderinteger[4]
            i5 = ladderinteger[5]
            i6 = ladderinteger[6]
            i7 = ladderinteger[7]
            i8 = ladderinteger[8]
            i9 = ladderinteger[9]
            i10 = ladderinteger[10]
            i11 = ladderinteger[11]
            i12 = ladderinteger[12]
            i13 = ladderinteger[13]
            i14 = ladderinteger[14]
            i15 = ladderinteger[15]
            o1 = ladderodds[1]
            o2 = ladderodds[2]
            o3 = ladderodds[3]
            o4 = ladderodds[4]
            o5 = ladderodds[5]
            o6 = ladderodds[6]
            o7 = ladderodds[7]
            o8 = ladderodds[8]
            o9 = ladderodds[9]
            o10 = ladderodds[10]
            o11 = ladderodds[11]
            o12 = ladderodds[12]
            o13 = ladderodds[13]
            o14 = ladderodds[14]
            o15 = ladderodds[15]

        i = i + 2
    print("s1: {}, s2: {}".format(s1,s2))
    return [starttime, datetime.now().timestamp(), start, end, ladderinteger, ladderodds, recordinteger, recordodds]

# %%
from datetime import datetime  
def SLengthRecordsEarlyMethod(end, 
                    start=2325, # generated by laddergenerator
                    ladderinteger=[2323, 871, 703, 667, 313, 235, 171, 129, 97, 73, 55, 25, 9, 7, 3, 1], # generated by laddergenerator
                    ladderodds=[66, 65, 62, 52, 47, 46, 45, 44, 43, 42, 41, 7, 6, 5, 2, 0], # generated by laddergenerator
                    recordinteger=[1, 3, 7, 9, 25, 27, 73, 97, 129, 171, 231, 313, 327, 703, 871, 1161], # generated by laddergenerator
                    recordodds=[0, 2, 5, 6, 7, 41, 42, 43, 44, 45, 46, 47, 52, 62, 65, 66], # generated by laddergenerator
                    printlines = False):
                     
    starttime = datetime.now().timestamp()
    lasttime = starttime
    ladderlength = len(ladderinteger) - 1
    currentrecordodds = ladderodds[0]
    
    # generated by laddergenerator
    i1 = ladderinteger[1]
    i2 = ladderinteger[2]
    i3 = ladderinteger[3]
    i4 = ladderinteger[4]
    i5 = ladderinteger[5]
    i6 = ladderinteger[6]
    i7 = ladderinteger[7]
    i8 = ladderinteger[8]
    i9 = ladderinteger[9]
    i10 = ladderinteger[10]
    i11 = ladderinteger[11]
    i12 = ladderinteger[12]
    i13 = ladderinteger[13]
    i14 = ladderinteger[14]
    i15 = ladderinteger[15]
    o1 = ladderodds[1]
    o2 = ladderodds[2]
 2839, 2851, 2873, 2899, 2927, 2945, 2995, 3017, 3041, 3071, 3091, 3139, 3167, 3185, 3215, 3233, 3283, 3305, 3329, 3359, 3377, 3415, 3427, 3449, 3475, 3503, 3521, 3571, 3593, 3617, 3649, 3667, 3715, 3737, 3761, 3791, 3811, 3859, 3881, 3905, 3935, 3953, 3977, 3991, 4003, 4025, 4051, 4079, 4097, 4147, 4169, 4193, 4223, 4243, 4291, 4313, 4337, 4367, 4385, 4435, 4463, 4481, 4511, 4529, 4567, 4579, 4601, 4627, 4655, 4673, 4723, 4745, 4769, 4799, 4819, 4867, 4889, 4913, 4951, 4961, 5011, 5033, 5057, 5087, 5107, 5143, 5155, 5177])
    skip5set = set([17, 45, 113, 189, 209, 257, 333, 401, 477, 533, 545, 573, 593, 621, 689, 765, 785, 833, 909, 977, 1055, 1109, 1121, 1169, 1197, 1217, 1265, 1341, 1361, 1409, 1485, 1553, 1629, 1685, 1697, 1745, 1773, 1841, 1869, 1917, 1937, 1985, 2061, 2129, 2205, 2261, 2273, 2321, 2351, 2417, 2493, 2513, 2561, 2637, 2705, 2781, 2837, 2849, 2897, 2925, 2993, 3069, 3089, 3137, 3165, 3213, 3281, 3357, 3413, 3425, 3473, 3501, 3569, 3647, 3665, 3713, 3789, 3809, 3857, 3933, 3989, 4001, 4049, 4077, 4145, 4221, 4241, 4289, 4365, 4433, 4461, 4509, 4565, 4577, 4625, 4653, 4721, 4797, 4817, 4865, 4949, 5009, 5085, 5105, 5141, 5153])
    skip6set = set([531, 571, 1053, 1107, 1683, 1867, 2259, 2349, 2835, 3163, 3411, 3645, 3987, 4459, 4563, 4947, 5139])
    skip7set = set([569, 1865, 3161, 4457, 4945])
    skip8set = set([4943])
    skip9set = set([4941])  
    
    i = start
    mask1 = 1
    while i < end:
       
        # generated by apriorigenerator
        r = (i % skipmodulus)
        if r in skip1set: i = i + 2
        elif r in skip2set: i = i + 4
        elif r in skip3set: i = i + 6
        elif r in skip4set: i = i + 8
        elif r in skip5set: i = i + 10
        elif r in skip6set: i = i + 12
        elif r in skip7set: i = i + 14
        elif r in skip8set: i = i + 16
        elif r in skip9set: i = i + 18

        n = i
        odds = 0
        while n != 1:
            n = 3*n + 1    
            # loop to minimize number of divisions
            if (n % 4) == 0:
                if (n % 8) == 0:
                    n = n // 8
                    if (n % 2) == 0:
                        if (n % 4) == 0:
                            n = n // 4
                            while (n % 2) == 0:
                                if (n % 4) == 0:
                                    n = n // 4
                                else:
                                    n = n // 2
                        else:
                            n = n // 2
                else:
                    n = n // 4
            else:
                n = n // 2
            odds = odds + 1
            newodds = currentrecordodds - odds
            
            # generated by laddergenerator
            if n <= i1:
                if o1 <= newodds: n = 1
                elif n <= i2:
                    if o2 <= newodds: n = 1
                    elif n <= i3:
                        if o3 <= newodds: n = 1
                        elif n <= i4:
                            if o4 <= newodds: n = 1
                            elif n <= i5:
                                if o5 <= newodds: n = 1
                                elif n <= i6:
                                    if o6 <= newodds: n = 1
                                    elif n <= i7:
                                        if o7 <= newodds: n = 1
                                        elif n <= i8:
                                            if o8 <= newodds: n = 1
                                            elif n <= i9:
                                                if o9 <= newodds: n = 1
                                                elif n <= i10:
                                                    if o10 <= newodds: n = 1
                                                    elif n <= i11:
                                                        if o11 <= newodds: n = 1
                                                        elif n <= i12:
                                                            if o12 <= newodds: n = 1
                                                            elif n <= i13:
                                                                if o13 <= newodds: n = 1
                                                                elif n <= i14:
                                                                    if o14 <= newodds: n = 1
                                                                    elif n <= i15:
                                                                        if o15 <= newodds: n = 1
                                                                        else:
                                                                            j = 16

                                                                            while (j < ladderlength) and (n <= ladderinteger[j]):        
                                                                                if ladderodds[j] <= newodds:
                                                                                    n = 1
                                                                                    break
                                                                                j = j + 1
        # update ladder if a full count meets previous record
        if currentrecordodds == odds:
            ladderinteger[0] = i 
        # log a new record reseting variables
        elif currentrecordodds < odds:
            if printlines:
                print("{} {} {}".format(i,odds,datetime.now().timestamp()-lasttime))
                lasttime = datetime.now().timestamp()
            recordinteger.append(i)
            recordodds.append(odds)
            currentrecordodds = odds
            ladderinteger.insert(0,i)
            ladderodds.insert(0,odds)
            ladderlength = ladderlength + 1
            
            # generated by laddergenerator
            i1 = ladderinteger[1]
            i2 = ladderinteger[2]
            i3 = ladderinteger[3]
            i4 = ladderinteger[4]
            i5 = ladderinteger[5]
            i6 = ladderinteger[6]
            i7 = ladderinteger[7]
            i8 = ladderinteger[8]
            i9 = ladderinteger[9]
            i10 = ladderinteger[10]
            i11 = ladderinteger[11]
            i12 = ladderinteger[12]
            i13 = ladderinteger[13]
            i14 = ladderinteger[14]
            i15 = ladderinteger[15]
            o1 = ladderodds[1]
            o2 = ladderodds[2]
            o3 = ladderodds[3]
            o4 = ladderodds[4]
            o5 = ladderodds[5]
            o6 = ladderodds[6]
            o7 = ladderodds[7]
            o8 = ladderodds[8]
            o9 = ladderodds[9]
            o10 = ladderodds[10]
            o11 = ladderodds[11]
            o12 = ladderodds[12]
            o13 = ladderodds[13]
            o14 = ladderodds[14]
            o15 = ladderodds[15]

        i = i + 2
    return [starttime, datetime.now().timestamp(), start, end, ladderinteger, ladderodds, recordinteger, recordodds]

# %%
reportSLengthRecords(SLengthRecords(10000000))
# Out:
# Sep 03, 2020 22:01:02 Seconds 7.4878480434417725 Odd Ints Per Second 667732.7679451433
# -------------
# Ladders [8400511, 6649279, 5649499, 3732423, 3542887, 3064033, 2298025, 1723519, 1564063, 1117065, 837799, 626331, 511935, 410011, 230631, 216367, 156159, 142587, 106239, 77031, 52527, 35655, 34239, 26623, 23529, 17647, 13255, 10971, 6171, 3711, 2919, 2463, 2323, 871, 703, 667, 313, 235, 171, 129, 97, 73, 55, 25, 9, 7, 3, 1] [256, 248, 228, 222, 217, 209, 208, 207, 197, 196, 195, 189, 174, 166, 164, 142, 141, 138, 130, 129, 125, 119, 114, 113, 103, 102, 101, 98, 96, 87, 79, 76, 66, 65, 62, 52, 47, 46, 45, 44, 43, 42, 41, 7, 6, 5, 2, 0]
# -------------
# ...

# %% [markdown]
# This is code to profile a call.

# %%
import cProfile
import re
import pstats
from pstats import SortKey
cProfile.run('SLengthRecords(10000000)', 'restats')
p = pstats.Stats('restats')
p.strip_dirs().sort_stats(-1).print_stats()

# %% [markdown]
# This is code to display a report from the output of SLengthRecords.

# %%
from datetime import datetime  
def reportSLengthRecords(datafromrun):
    starttime = datafromrun[0]
    endtime = datafromrun[1]
    startint = datafromrun[2]
    endint = datafromrun[3]
    ladderinteger = datafromrun[4]
    ladderodds = datafromrun[5]
    recordinteger = datafromrun[6]
    recordodds = datafromrun[7]
    elapsedtime = endtime - starttime
    oddspersecond = (endint - startint)/(2*elapsedtime) 
    spacer = "-------------"
    print("{} Seconds {} Odd Ints Per Second {}".\
          format(datetime.now().strftime("%b %d, %Y %H:%M:%S"),elapsedtime,oddspersecond))
    print("{}".format(spacer))
    print("Ladders")
    print("INTEGERS  {}".format(ladderinteger))
    print("ODD STEPS {}".format(ladderodds))
    print("{}".format(spacer))
    print("Records")
    print("INTEGERS  {}".format(recordinteger))
    print("ODD STEPS {}".format(recordodds))
    print("{}".format(spacer))
    
    expectedladderinteger = [670617279, 268549803, 226588897, 169941673, 127456255, 36791535, 15733191, 14934241, 
                            11200681, 8400511, 6649279, 5649499, 3732423, 3542887, 3064033, 2298025, 1723519, 1564063, 
                            1126015, 837799, 626331, 511935, 410011, 230631, 216367, 156159, 142587, 106239, 77031, 
                            52527, 35655, 35497, 26623, 23529, 17673, 13255, 10971, 6171, 3711, 2919, 2463, 2323, 871, 
                            703, 667, 313, 235, 171, 129, 97, 73, 55, 25, 9, 7, 3, 1] 
    expectedrecordinteger = [1, 3, 7, 9, 25, 27, 73, 97, 129, 171, 231, 313, 327, 703, 871, 1161, 2463, 2919, 3711, 6171, 10971, 13255, 17647, 23529, 26623, 
                            34239, 35655, 52527, 77031, 106239, 142587, 156159, 216367, 230631, 410011, 511935, 626331,
                            837799, 1117065, 1501353, 1723519, 2298025, 3064033, 3542887, 3732423, 5649499, 6649279, 
                            8400511, 11200681, 14934241, 15733191, 36791535, 63728127, 169941673, 226588897, 
                            268549803, 670617279]
    expectedrecordodds = [0, 2, 5, 6, 7, 41, 42, 43, 44, 45, 46, 47, 52, 62, 65, 66, 76, 79, 87, 96, 98, 101, 102, 103, 113, 114, 119, 125, 129, 130, 138, 141,
                        142, 164, 166, 174, 189, 195, 196, 197, 207, 208, 209, 217, 222, 228, 248, 256, 257, 258, 263,
                        278, 357, 358, 359, 362, 370]

    lastindex = len(recordinteger)
    ladderindex = len(expectedladderinteger) - len(ladderinteger)
    if expectedladderinteger[ladderindex:] == ladderinteger:
        print("Ladder integers PASS.")
    else:
        print("Ladder integers DO NOT PASS.")
        print("Received: {}".format(ladderinteger))
        print("Expected: {}".format(expectedladderinteger[ladderindex:]))
        print(" ")
        D = [(ladderinteger[i],expectedladderinteger[ladderindex:][i]) for i in range(len(ladderinteger)) if ladderinteger[i] != expectedladderinteger[ladderindex:][i]]
        print("(Received,Expected) : {}".format(D))
        print("{}".format(spacer))
    if expectedrecordinteger[:lastindex] == recordinteger:
        print("Record integers PASS.")
    else:
        print("Record integers DO NOT PASS.")
        print("Received: {}".format(recordinteger))
        print("Expected: {}".format(expectedrecordinteger[:lastindex]))
        print(" ")
        D = [(recordinteger[i],expectedrecordinteger[:lastindex][i]) for i in range(len(recordinteger)) if recordinteger[i] != expectedrecordinteger[:lastindex][i]]
        print("(Received,Expected) : {}".format(D))
        print("{}".format(spacer))
    if expectedrecordodds[:lastindex] == recordodds:
        print("Record delays   PASS.")
    else:
        print("Record delays   DO NOT PASS.")
        print("Received: {}".format(recordodds))
        print("Expected: {}".format(expectedrecordodds[:lastindex]))
        print(" ")
        D = [(recordodds[i],expectedrecordodds[:lastindex][i]) for i in range(len(recordodds)) if recordodds[i] != expectedrecordodds[:lastindex][i]]
        print("(Received,Expected) : {}".format(D))
        print("{}".format(spacer))

# %% [markdown]
# This procedure presents properties of a particular integer.

# %%
import math
def trajectory(n):
    C = [n]
    maximum = [0,n]
    start = n
    glide = []
    i = 0
    even = 0
    odd = 0
    while n % 2 == 0:
       n = n // 2
       C.append(n)
       even = even + 1
       i = i + 1
       if glide == []:
            glide = [i,n]
    T = [n]                       # sequence
    S = [n]
    Splus = [[n,n%8]]
    while n > 1:   # cycles add multiple loops to 1 before stopping
        if n % 2 == 1:
            n = (3*n + 1)                 # Collatz function
            C.append(n)
            i = i + 1
            if n > maximum[1]:
                maximum = [i,n]
            odd = odd + 1
            n = n // 2
            i = i + 1
            if n < start:
                if glide == []:
                    glide = [i,n]
            T.append(n)
            C.append(n)
            even = even + 1
        while n % 2 == 0:           # if n is even keep dividing by 2
            n = n // 2              # divide by 2
            i = i + 1
            if n < start:
                if glide == []:
                    glide = [i,n]
            T.append(n)         # count that the division occurred
            C.append(n)
            even = even + 1
        S.append(n)
        Splus.append([n,n%8])  
        # add the new n to the list
    print("C  {}".format(C))
    print(" ")
    print("T  {}".format(T))
    print(" ")
    print("S  {}".format(S))
    print(" ")
    print("Splus {}".format(Splus))
    print("Delay        {}".format(odd + even))
    print("Glide        {}".format(glide))
    print("Maximum      {}".format(maximum))
    print("Odd          {}".format(odd))
    print("Even         {}".format(even))
    strength = 5*odd - 3*even
    print("Strength     {}".format(strength))
    print("Level        {}".format(math.floor(-strength/8)))
    residue = math.pow(2,even)/(math.pow(3,odd)*start)
    residue2 = 2^even - 3^odd*start
    residue3 = 1 - (math.pow(3,odd)*start)/math.pow(2,even)
    #print("Residue      {} = {}/{} = {}".format(residue,factor(residue.numerator()),factor(residue.denominator()),RR(residue)))
    #print("Residue2     {} = {}".format(residue2,factor(residue2)))
    #print("Residue3     {} = {}/{} = {}".format(residue3,factor(residue3.numerator()),factor(residue3.denominator()),RR(residue3)))
    #gamma = even/ln(start)
    #print("Gamma        {} = {}".format(gamma,RR(gamma)))
    completeness = odd/even
    #maxcompleteness = ln(start)/even
    #lntwothree = ln(2)/ln(3)
    #print("Completeness {}: {} < {} < {}".format(completeness,RR(maxcompleteness),RR(completeness),RR(lntwothree)))

# %%
trajectory(27)
# Out:
# C  [27, 82, 41, 124, 62, 31, 94, 47, 142, 71, 214, 107, 322, 161, 484, 242, 121, 364, 182, 91, 274, 137, 412, 206, 103, 310, 155, 466, 233, 700, 350, 175, 526, 263, 790, 395, 1186, 593, 1780, 890, 445, 1336, 668, 334, 167, 502, 251, 754, 377, 1132, 566, 283, 850, 425, 1276, 638, 319, 958, 479, 1438, 719, 2158, 1079, 3238, 1619, 4858, 2429, 7288, 3644, 1822, 911, 2734, 1367, 4102, 2051, 6154, 3077, 9232, 4616, 2308, 1154, 577, 1732, 866, 433, 1300, 650, 325, 976, 488, 244, 122, 61, 184, 92, 46, 23, 70, 35, 106, 53, 160, 80, 40, 20, 10, 5, 16, 8, 4, 2, 1]
#
# T  [27, 41, 62, 31, 47, 71, 107, 161, 242, 121, 182, 91, 137, 206, 103, 155, 233, 350, 175, 263, 395, 593, 890, 445, 668, 334, 167, 251, 377, 566, 283, 425, 638, 319, 479, 719, 1079, 1619, 2429, 3644, 1822, 911, 1367, 2051, 3077, 4616, 2308, 1154, 577, 866, 433, 650, 325, 488, 244, 122, 61, 92, 46, 23, 35, 53, 80, 40, 20, 10, 5, 8, 4, 2, 1]
#
# ...

# %%
def equivalencegenerator(powerof2,showdetails=False):
    spacer = "-----------------------------------------"
    source = "# generated by equivalencegenerator"
    offset = 3
    groupsize = 4
    groups = powerof2 // groupsize
    twos = [powerof2]
    temp = powerof2

    while temp > groupsize:
        temp = temp // 2
        twos.append(temp)
    
    print("{}{}".format("\t"*offset,source))
    print("{}res = (n % {})".format("\t"*offset,powerof2))
    j = 1
    
    for i in range (1,powerof2,2):
        R = i
        C = powerof2
        R2 = i
        C2 = powerof2
        odds = 0
        r = 0
        c = 1
        g = 1
        
        if showdetails:
            print("({}m + {}) = ({}*n + {})/{}   : odds = {}".format(C,R,c,r,g,odds))
        
        while (((C % 2) == 0) and ((R % 2) == 1)):
            C = 3*C
            R = 3*R + 1
            C2 = 3*C2
            R2 = 3*R2 + g
            c = 3*c
            r = 3*r + g
            while ((C % 2) == 0) and ((R % 2) == 0):
                g = 2*g
                R = R//2
                C = C//2

            if ((C % 2) == 0) and ((R % 2) == 1):
                odds = odds + 1
            if showdetails:
                print("({}m + {})/{} = {}m + {} = ({}*n + {})/{}   : odds = {}".format(C2,R2,g,C,R,c,r,g,odds))
                
        for t in range(0,len(twos)-1):
            spacing = offset + t
            if (i % twos[t]) == 1:
                print("{}if res < {}:".format("\t"*spacing,i - 1 + (twos[t] // 2)))
            elif (i % twos[t]) == (1 + (twos[t] // 2)) and (twos[t] != 4):
                print("{}else:".format("\t"*spacing))   
                
        spacing = offset + len(twos) - 1
        if (i % 4) == 1:
            if odds > 0:  
                print("{}if res == {}: n = ({}*n + {}) // {}; odds = odds + {}".format("\t"*spacing,i,c,r,g,odds))
            else:
                print("{}if res == {}: n = ({}*n + {}) // {}".format("\t"*spacing,i,c,r,g))
        else:
            if odds > 0:  
                print("{}else: n = ({}*n + {}) // {}; odds = odds + {}".format("\t"*spacing,c,r,g,odds))
            else:
                print("{}else: n = ({}*n + {}) // {}".format("\t"*spacing,c,r,g))

# %%
import math
def apriorigenerator(modulus):
    a = []
    skip = []
    count = 0
    i = 1
    while i < modulus:
        p = AttemptProof(modulus, i)
        if p[0] not in ['U','P']:
            a.append(i)
        i = i + 2
    i = modulus - 1
    while i > 0:
        if i in a:
            if count == len(skip):
                skip.append([])
            skip[count].insert(0,i)
            count = count + 1
        else:
            count = 0
        i = i - 2
    skip.insert(0,a)
    genstring = "# generated by apriorigenerator"
    spacer = "----------"
    print("\t{}".format(genstring))
    print("\tskipmodulus = {}".format(modulus))
    for i in range(1,len(skip)):
        print("\tskip{}set = set({})".format(i,skip[i]))    
    print(spacer)
    print("\t\t{}".format(genstring))
    print("\t\tr = (i % skipmodulus)")
    for i in range(1,len(skip)):
        if i == 1:
            print("\t\tif r in skip{}set: i = i + {}".format(i,2*i))
        else:
            print("\t\telif r in skip{}set: i = i + {}".format(i,2*i))
        i = i + 1

# %%
def laddergenerator(quantity):
    ladderinteger = [8400511, 6649279, 5649499, 3732423, 3542887, 3064033, 2298025, 1723519, 1564063, 1117065, 
                      837799, 626331, 511935, 410011, 230631, 216367, 156159, 142587, 106239, 77031, 52527, 
                      35655, 34239, 26623, 23529, 17647, 13255, 10971, 6171, 3711, 2919, 2463, 2323, 871, 703, 
                      667, 313, 235, 171, 129, 97, 73, 55, 25, 9, 7, 3, 1]
    ladderodds = [256, 248, 228, 222, 217, 209, 208, 207, 197, 196, 195, 189, 174, 166, 164, 142, 141, 138, 130, 
                  129, 125, 119, 114, 113, 103, 102, 101, 98, 96, 87, 79, 76, 66, 65, 62, 52, 47, 46, 45, 44, 
                  43, 42, 41, 7, 6, 5, 2, 0]
    recordinteger = [1, 3, 7, 9, 25, 27, 73, 97, 129, 171, 231, 313, 327, 703, 871, 1161, 2463, 2919, 3711, 
                     6171, 10971, 13255, 17647, 23529, 26623, 34239, 35655, 52527, 77031, 106239, 142587, 156159, 
                     216367, 230631, 410011, 511935, 626331, 837799, 1117065, 1501353, 1723519, 2298025, 3064033, 
                     3542887, 3732423, 5649499, 6649279, 8400511, 11200681, 14934241, 15733191, 36791535, 63728127, 
                     169941673, 226588897, 268549803, 670617279]
    recordodds = [0, 2, 5, 6, 7, 41, 42, 43, 44, 45, 46, 47, 52, 62, 65, 66, 76, 79, 87, 96, 98, 101, 102, 103, 113, 
                  114, 119, 125, 129, 130, 138, 141, 142, 164, 166, 174, 189, 195, 196, 197, 207, 208, 209, 217, 222, 
                  228, 248, 256, 257, 258, 263, 278, 357, 358, 359, 362, 370]
    recordintegers = []
    source = "# generated by laddergenerator with input " + str(quantity)
#    print("\t\tstart={}, {}".format(ladderinteger[-quantity-1]+2,source))
#    print("\t\tladderinteger={}, {}".format(ladderinteger[-quantity-1:],source))
    #print("ladderodds={}, {}".format(ladderodds[-quantity-1:],source))
#    print("\t\trecordinteger={}, {}".format(recordinteger[:quantity+1],source))
#    print("\t\trecordodds={}, {}".format(recordodds[:quantity+1:],source))
 #   print("-------------")
    print("\t"+source)
    for i in range (1,quantity+1):
        print("\ti{} = ladderinteger[{}]".format(i,i))
    for i in range (1,quantity+1):
        print("\to{} = ladderodds[{}]".format(i,i))
    print("-------------")
    print(source)
    for i in range (1,quantity+1):
        if i == 1:
            print("{}if n <= i{}:".format("\t"*i,i))
        else:
            print("{}elif n <= i{}:".format("\t"*i,i))
        print("{}if o{} <= newodds: n = 1".format("\t"*(i+1),i))
    print("{}else:".format("\t"*i))
    print("{}j = {}".format("\t"*(i+1),quantity+1))
    print()
